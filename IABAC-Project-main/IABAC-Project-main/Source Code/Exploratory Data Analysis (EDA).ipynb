# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import warnings; warnings.filterwarnings("ignore")

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_excel("INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls")

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# ...

# %%
df.tail()
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
# 1197   E100994   50    Male             Medical       Married   Development
# 1198   E100995   34  Female             Medical        Single  Data Science
# 1199   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# ...

# %%
df.shape
# Out:
# (1200, 28)

# %%
df.isnull().sum().any()       # There is no missing values in this Dataset
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
df.describe(include=['O'])    # To see the Distribution of Categorical features
# Out:
#        EmpNumber Gender EducationBackground MaritalStatus EmpDepartment  \
# count       1200   1200                1200          1200          1200
# unique      1200      2                   6             3             6
# top     E1001000   Male       Life Sciences       Married         Sales
# freq           1    725                 492           548           373
#
#              EmpJobRole BusinessTravelFrequency OverTime Attrition
# count              1200                    1200     1200      1200
# unique               19                       3        2         2
# top     Sales Executive           Travel_Rarely       No        No
# freq                270                     846      847      1022

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %%
df.duplicated().sum()      # There is No duplicate values
# Out:
# 0

# %% [markdown]
# -------

# %% [markdown]
# ###### PerformanceRating

# %%
plt.figure(figsize = (11,5))
plt.subplot(1,2,1)
sns.countplot(df["PerformanceRating"])             
plt.subplot(1,2,2)
df["PerformanceRating"].value_counts().plot(kind = "pie",autopct = '%1.0f%%',
                                            colors=['tomato', 'gold', 'skyblue']);

# %% [markdown]
# - The performance rating is given a value of 2,3 & 4.
# - from above visualization we see that the dataset is imbalanced
# - 73% of our data has a performance_rating as 3

# %% [markdown]
# ----------------

# %% [markdown]
# ###### Attrition

# %%
plt.figure(figsize = (25,15))
plt.subplot(2,3,1)
sns.countplot(df["Attrition"], hue = df["Gender"])
plt.subplot(2,3,2)
sns.countplot(df["Attrition"], hue = df["PerformanceRating"])
plt.subplot(2,3,3)
sns.barplot(x='Attrition',y= 'PerformanceRating', hue = 'OverTime', data = df)
plt.subplot(2,3,4)
Y_count = len(df[df['Attrition'] == 'Yes'])
N_count = len(df[df['Attrition'] == 'No'])
# create data
names='Yes', 'No',
size=[Y_count,N_count]
plt.pie(size,labels= names, colors=['lightcoral','cornflowerblue'],autopct='%1.0f%%')
plt.subplot(2,3,5)
sns.boxplot(df["Attrition"],df["DistanceFromHome"])
plt.subplot(2,3,6)
sns.barplot(df["Attrition"],df["ExperienceYearsAtThisCompany"]);

# %% [markdown]
# - Attrition, in Human Resource terminology, refers to the phenomenon of the employees leaving the company.
# - only **15%** of the employees attrit from the company. i.e **85%** of the employee stay with company.
# - As distance from home increases for a employee, he/she is more likely to get attrit.
# - attrition rate for males are more compared to female.

# %% [markdown]
# -------

# %% [markdown]
# ###### Age

# %%
plt.figure(figsize = (19,11))
plt.subplot(2,2,1)
sns.distplot(df["Age"])
plt.subplot(2,2,2)
sns.scatterplot(df["Age"],df["TotalWorkExperienceInYears"])
plt.subplot(2,2,3)
sns.kdeplot(df["Age"],df["EmpHourlyRate"],fill = True)
plt.subplot(2,2,4)
sns.kdeplot(df["Age"],df["ExperienceYearsInCurrentRole"],fill= True);

# %% [markdown]
# - The age column is normally distributed
# - the mean & median age is 36 years
# - most of the employees are of age range from 30-43 years.
# - We see that Total work experience increases with Age which is a universal Truth.
# - Employee age range from 30- 40 has good hourly rate.

# %% [markdown]
# ---------------

# %% [markdown]
# ###### EducationBackground

# %%
# relationship between target and EducationBackground
plt.figure(figsize = (12,17))
plt.subplot(3,1,1)
sns.countplot(df["EducationBackground"],hue = df["PerformanceRating"],order= df["EducationBackground"].value_counts().index)
plt.subplot(3,1,2)
sns.barplot(x='EducationBackground',y='PerformanceRating',hue = 'PerformanceRating', data=df)
plt.legend(loc = 0)
plt.subplot(3,1,3)
sns.countplot(df["EducationBackground"]);

# %% [markdown]
# - we see that most of the empoyees are from medical related background(Life-science and Medical).
# - There are very few employees from Human Resource background.
# - Life_science and Medical Educationbackground as high performance ratings followed by marketing background
# - Human resource Educationalbackground has least performance ratings.

# %% [markdown]
# -------------

# %% [markdown]
# ###### Gender

# %%
# gender vs Target
plt.figure(figsize = (18,7))
plt.subplot(1,3,1)
df["Gender"].value_counts().plot(kind = "pie",autopct = '%1.0f%%',
                                            colors=['tomato', 'gold', 'skyblue'])
plt.subplot(1,3,2)
sns.countplot(df["Gender"], hue = df["PerformanceRating"])
plt.subplot(1,3,3)
sns.barplot(x='Gender',y='PerformanceRating',hue = 'PerformanceRating', data = df)
plt.legend(loc = 0);

# %% [markdown]
# - In above Visualization 60% of employees are male and 40% are female
# - since male employees are more, the Total performance_ratings is more for men, when compared to women.

# %% [markdown]
# --------

# %% [markdown]
# ###### MaritalStatus

# %%
# relationship between target and MaritalStatus
plt.figure(figsize = (18,7))
plt.subplot(1,3,1)
df["MaritalStatus"].value_counts().plot(kind = "pie",autopct = '%1.0f%%',
                                colors = ['tomato', 'gold', 'skyblue','tab:orange','tab:cyan','tab:brown'])
plt.subplot(1,3,2)
sns.countplot(df["MaritalStatus"], hue = df["PerformanceRating"])
plt.subplot(1,3,3)
sns.barplot(x='MaritalStatus',y='PerformanceRating', hue="Gender", data = df)
plt.legend(loc = 0);

# %% [markdown]
# - Most of the employees are married 46%, only 32% are single.
# - We see that performence is slightly higher for employees who are single, than married.

# %% [markdown]
# ----------

# %% [markdown]
# ###### EmpDepartment

# %%
round(df.groupby(by='EmpDepartment')['PerformanceRating'].mean(),2)
# Out:
# EmpDepartment
# Data Science              3.05
# Development               3.09
# Finance                   2.78
# Human Resources           2.93
# Research & Development    2.92
# Sales                     2.86
# Name: PerformanceRating, dtype: float64

# %%
# Slicing the all coloums to analyze each department separately
sales = df[df.EmpDepartment == 'Sales']
HR = df[df.EmpDepartment == 'Human Resources']
Development = df[df.EmpDepartment == 'Development']
Data_Science = df[df.EmpDepartment == 'Data Science']
RD = df[df.EmpDepartment == 'Research & Development']
Finance = df[df.EmpDepartment == 'Finance']

# %%
plt.figure(figsize=(30,17))
plt.subplot(2,3,1)
sns.boxplot(sales['PerformanceRating'], sales['Age'])
plt.xlabel("sales_performance")
plt.subplot(2,3,2)
sns.barplot(sales['Gender'], sales['PerformanceRating'])
plt.xlabel("sales_performance")
plt.subplot(2,3,3)
sns.countplot(x="PerformanceRating", data=sales, palette="Greens_d")
plt.xlabel("sales_performance")
plt.subplot(2,3,4)
sns.barplot(sales["TotalWorkExperienceInYears"],sales["PerformanceRating"])
plt.xlabel("sales_workExp")
plt.subplot(2,3,5)
sns.countplot(x = "PerformanceRating", data=HR, palette="Greens_d")
plt.xlabel("HR_performance")
plt.subplot(2,3,6)
sns.boxplot(HR['PerformanceRating'], HR['Age'])
plt.xlabel("HR_performance")
plt.show()

# %%
plt.figure(figsize=(30,17))
plt.subplot(2,3,1)
sns.barplot(HR['Gender'], HR['PerformanceRating'])
plt.xlabel("HR_performance")
plt.subplot(2,3,2)
sns.barplot(HR["TotalWorkExperienceInYears"],HR["PerformanceRating"])
plt.xlabel("HR_workExp")
plt.subplot(2,3,3)
sns.countplot(x = "PerformanceRating", data=Development, palette="Greens_d")
plt.xlabel("Development_performance")
plt.subplot(2,3,4)
sns.boxplot(Development['PerformanceRating'], Development['Age'])
plt.xlabel("Development_performance")
plt.subplot(2,3,5)
sns.barplot(Development['Gender'], Development['PerformanceRating'])
plt.xlabel("Development_performance")
plt.subplot(2,3,6)
sns.barplot(Development["TotalWorkExperienceInYears"],Development["PerformanceRating"])
plt.xlabel("Development_workExp")
plt.show()

# %%
plt.figure(figsize=(30,17))
plt.subplot(2,3,1)
sns.countplot(x = "PerformanceRating", data=Data_Science, palette="Greens_d")
plt.xlabel("Data_Science performance")
plt.subplot(2,3,2)
sns.boxplot(Data_Science['PerformanceRating'], Data_Science['Age'])
plt.xlabel("Data_Science performance")
plt.subplot(2,3,3)
sns.barplot(Data_Science['Gender'], Data_Science['PerformanceRating'])
plt.xlabel("Data_Science performance")
plt.subplot(2,3,4)
sns.barplot(Data_Science["TotalWorkExperienceInYears"],Data_Science["PerformanceRating"])
plt.xlabel("Data_Science WorkExperience")
plt.subplot(2,3,5)
sns.countplot(x = "PerformanceRating", data=RD, palette="Greens_d")
plt.xlabel("RD performance")
plt.subplot(2,3,6)
sns.boxplot(RD['PerformanceRating'], RD['Age'])
plt.xlabel("RD performance")
plt.show()

# %%
plt.figure(figsize=(30,17))
plt.subplot(2,3,1)
sns.barplot(RD['Gender'], RD['PerformanceRating'])
plt.xlabel("RD performance")
plt.subplot(2,3,2)
sns.barplot(RD["TotalWorkExperienceInYears"],RD["PerformanceRating"])
plt.xlabel("RD WorkExperience")
plt.subplot(2,3,3)
sns.countplot(x = "PerformanceRating", data=Finance, palette="Greens_d")
plt.xlabel("Finance performance")
plt.subplot(2,3,4)
sns.boxplot(Finance['PerformanceRating'], Finance['Age'])
plt.xlabel("Finance performance")
plt.subplot(2,3,5)
sns.barplot(Finance['Gender'], Finance['PerformanceRating'])
plt.xlabel("Finance performance")
plt.subplot(2,3,6)
sns.barplot(Finance["TotalWorkExperienceInYears"],Finance["PerformanceRating"])
plt.xlabel("Finance WorkExperience")
plt.show()

# %%
plt.figure(figsize = (32,8))
plt.subplot(1,3,1)
sns.countplot(df["EmpDepartment"])
plt.subplot(1,3,2)
sns.countplot(df["EmpDepartment"], hue = df["PerformanceRating"])
plt.subplot(1,3,3)
sns.barplot(x='EmpDepartment',y='PerformanceRating',data = df)
plt.show()

# %% [markdown]
# - In Employee department feature there are six departments available.  \
#     1) Sales, 2) Human Resoruces, 3) Development, 4) Data Science, 5) Reserch & Devlopment, 6) Finance
# - The mean performance of **Data_science** and **Development** Department is more, when compared to other department
#
#
# - **Sales:** The Performace rating level 3 is more in the sales department. The total work experience increses performance rating also increases.
#
# - **Human Resources:** The majority of the employees lying under the level 3 performance. The older people are performing low in this department. The female employees in HR department doing really well in their performance. The total work experience does not make any difference to performance in this department.
#
# - **Development:** The largest number of employees are level 3 performers. Employees of all age are performing at the level of 3 only. The gender-based performance is nearly same for both.
#
# - **Data Science:** The highest average of level 3 performance is in data science department. Data science is the only department where less number of level 2 performers. The overall performance is higher compared to all departments. The age does not count as an important factor in their performance. Male employees are doing good in this department. The number of work experience does not matter.
#
# - **Research & Development:** The age factor is not deviating from the level of performance here where different employees with different age are there in every level of performance. The R&D has the good female employees in their performance.
#
# - **Finance:** The finance department performance is exponentially decreasing when age increases. The male employees are doing good. The experience factor is inversely relating to the performance level.

# %% [markdown]
# ------------------

# %% [markdown]
# ###### EmpJobRole

# %%
# relationship between target and EmpJobRole
plt.figure(figsize = (20,30))
plt.subplot(3,1,1)
sns.countplot(df["EmpJobRole"])
plt.xticks(rotation = 45)
plt.subplot(3,1,2)
sns.countplot(df["EmpJobRole"], hue = df["PerformanceRating"])
plt.xticks(rotation = 45)
plt.subplot(3,1,3)
sns.barplot(x='EmpJobRole',y='PerformanceRating',data=df,)
plt.xticks(rotation = 45);

# %% [markdown]
# - There are total 19 different types of Job Role
# - the top 2 job role are sales executive **22%** and developer **20%** of all total job role.
# - developer, data_scientist & Business analyst has slightly more performance_ratings than other job role.

# %% [markdown]
# ---------------

# %% [markdown]
# ###### BusinessTravelFrequency

# %%
# relationship between target and BusinessTravelFrequency
plt.figure(figsize = (18,7))
plt.subplot(1,3,1)
sns.countplot(df["BusinessTravelFrequency"])
plt.subplot(1,3,2)
sns.countplot(df["BusinessTravelFrequency"], hue = df["PerformanceRating"])
plt.subplot(1,3,3)
sns.barplot(x='BusinessTravelFrequency',y='PerformanceRating', data = df);

# %% [markdown]
# - Most of the employees travel rarely
# - As we can see in the above plot there is much change in performance rating based on business travel_frequency.

# %% [markdown]
# ----------

# %% [markdown]
# ###### DistanceFromHome

# %%
sns.jointplot(df["DistanceFromHome"],df["PerformanceRating"]);

# %% [markdown]
# - Distance from home has more number of level 3 performance ratings
# - Most of the employees are near from the work place.
# - The distance from home to office is distributing from 0 unit to 25 unit which can be kilometre or mile. The most of the employees are coming from the range of 0 to 5 units

# %% [markdown]
# -----------------------

# %% [markdown]
# ##### EmpHourlyRate

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,2,1)
sns.distplot(df["EmpHourlyRate"])
plt.subplot(2,2,2)
sns.boxplot(df["PerformanceRating"],df["EmpHourlyRate"])
plt.subplot(2,2,3)
sns.barplot(df["EmpJobInvolvement"],df["EmpHourlyRate"])
plt.subplot(2,2,4)
sns.kdeplot(df["EmpHourlyRate"],df["ExperienceYearsAtThisCompany"], fill = True);

# %% [markdown]
# - The hourly rate range is 45 to 90 for majority employees work in this company.
# - For Job_involvement level 4 has more hourly rate.
# - hourly rate is good for the employees with 1 -12 years experience at this company.

# %% [markdown]
# -----------

# %% [markdown]
# ##### EmpEducationLevel

# %%
plt.figure(figsize=(30,17))
plt.subplot(2,3,1)
df["EmpEducationLevel"].value_counts().plot(kind = "pie",autopct = '%1.0f%%',
                                colors = ['tomato', 'gold', 'skyblue','tab:orange','tab:cyan','tab:brown'])
plt.subplot(2,3,2)
sns.barplot(df["EmpEducationLevel"], df["PerformanceRating"])
plt.subplot(2,3,3)
sns.kdeplot(df["EmpEducationLevel"],df['EmpHourlyRate'], fill = True)
plt.subplot(2,3,4)
sns.kdeplot(df["EmpEducationLevel"],df['EmpLastSalaryHikePercent'], fill = True)
plt.subplot(2,3,5)
sns.kdeplot(df["EmpEducationLevel"],df['ExperienceYearsInCurrentRole'], fill = True)
plt.subplot(2,3,6)
sns.kdeplot(df["EmpEducationLevel"],df['YearsSinceLastPromotion'], fill = True);

# %% [markdown]
# - Most of the employees are having education level 3 and 4.
# - Education level 3 consists of **37%** and level 4 consists of **27%**.
# - Most of the employees get 11% to 20% of salary hike in this company.
# - Employees with education level 3 has high performance ratings.

# %% [markdown]
# ------------

# %% [markdown]
# ##### TotalWorkExperienceInYears

# %%
plt.figure(figsize=(30,17))
plt.subplot(2,3,1)
sns.distplot(df["TotalWorkExperienceInYears"])
plt.subplot(2,3,2)
sns.boxplot(df['PerformanceRating'],df["TotalWorkExperienceInYears"])
plt.subplot(2,3,3)
sns.barplot(df["Gender"],df["TotalWorkExperienceInYears"])
plt.subplot(2,3,4)
sns.boxplot(df["Attrition"],df["TotalWorkExperienceInYears"])
plt.subplot(2,3,5)
sns.kdeplot(df['TotalWorkExperienceInYears'],df["YearsSinceLastPromotion"],fill = True)
plt.subplot(2,3,6)
sns.kdeplot(df['TotalWorkExperienceInYears'],df["EmpJobInvolvement"],fill = True);

# %% [markdown]
# - on an average employees has a  total work experience of **10** years.
# - Most employees has work experience from range **1-12** years.
# - The performance ratings is better for employees with work experience **5-14** years.
# - Female employees has more total work experience.
# - employees with less experience is more likely to quit organisation.
# - employees with total work experience **2-12** years get promotion early.

# %% [markdown]
# ----------

# %% [markdown]
# #### Correlation of Features

# %%
plt.figure(figsize = (12,5))
df.corr()["PerformanceRating"].sort_values().drop("PerformanceRating").plot(kind = "bar");

# %%
plt.figure(figsize = (21,16))
sns.heatmap(df.corr(),annot = True,cmap = 'gnuplot');

# %% [markdown]
# **From the above correlation plot, we can be to see that correlation between features with numerical values in the dataset. The heat signatures show the level of correlation from 0 to 1. from this distribution we can derive the facts as follows..**
#
# - The Total years of experience and job level are having the higher correlation when comparing to all features.
# - Experience years at this company and years with the current manager has the second higher relation between these features.
# - Experience years at this company and experience in the current role makes the sense of correlation.
# - People who have more experience with the company has the more probability to get the promotion from the correlation between them.
# - In this plot, the age has the important role in the total number of work experience of an employee.
# - These Top 3 factors has positive corelation with performance ratings \
#   1) Employee Environment Satisfaction  \
#   2) Employee Last_Salary Hike Percent  \
#   3) Employee Work Life Balance  \
#   When these factors increases the performance rating also increases
# - These Top 3 factors has Negative corelation with performance ratings \
#    1) Years Since Last Promotion
#    2) Experience Years In_Current Role
#    3) Years With Current Manager  \
#    When these factors increases the performance rating Decreases.

# %% [markdown]
# -----------------
